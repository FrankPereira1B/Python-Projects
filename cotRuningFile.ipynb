# %%
#Importing the Libraries
import pandas as pd
import numpy as np
from scrapingCotFunction import scraping

# %%
#Data Import
data = pd.read_excel(r"C:\Users\pereifr\OneDrive - EY\Desktop\cot\05 Jan.xlsx")

# %%
# Passing the data and Checking the outputs / COT Report
Combined = scraping(data)

# %%
Combined
# Out:
#                      NCLong  NCShort NCSpreads    CLong   CShort    TLong  \
# No
# RUBLETP               7,509    6,684         0   15,572   16,923   23,081
# RUBLEOI                29.8     26.6       0.0     61.9     67.3     91.7
# RUBLETO                  14       14         0       10        8       24
# CADTP                41,560   27,036     2,440   71,354  109,613  115,354
# CADOI                  26.6     17.3       1.6     45.7     70.2     73.9
# CADTO                    30       15        12       35       32       71
# CHFTP                17,386    8,014         4    9,246   29,386   26,636
# CHFOI                  35.5     16.3       0.0     18.9     59.9     54.3
# CHFTO                    14        9         1       14       13       29
# PESOTP               52,578   60,301     1,418   79,574   76,962  133,570
# PESOOI                 37.2     42.7       1.0     56.3     54.5     94.5
# PESOTO                   65       34         6       32       27      101
# ...

# %%
Combined.to_excel(r"C:\Users\pereifr\OneDrive - EY\Desktop\cot\Reports\05 Jan.xlsx")
